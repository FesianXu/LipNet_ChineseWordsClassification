# %%
import numpy as np
import pandas as pd

# %%
preds = pd.read_csv('./predicts.csv', header=None)

# %%
count = {}
for index, row in preds.iterrows():
    if row[1] in count:
        count[row[1]] += 1
    else:
        count[row[1]] = 0

# %%
count
# Out:
# {'一下': 8,
#  '一个': 12,
#  '一些': 8,
#  '一切': 15,
#  '一如既往': 7,
#  '一定': 5,
#  '一年一度': 9,
#  '一应俱全': 7,
#  '一样': 11,
#  '一点': 6,
#  '一目了然': 6,
#  '一般': 7,
#  '一见钟情': 7,
#  '三位一体': 6,
#  '下来': 4,
#  '下落不明': 8,
#  '不仅': 8,
#  '不会': 6,
#  '不可思议': 8,
#  '不同': 6,
#  '不得而知': 7,
#  '不折不扣': 6,
#  '不是': 9,
#  '不正之风': 6,
#  '不知不觉': 7,
#  '不约而同': 7,
#  '不能': 9,
#  '不言而喻': 7,
#  '不过': 5,
#  '不遗余力': 8,
#  '与众不同': 6,
#  '世界': 7,
#  '东西': 10,
#  '中国': 11,
#  '丰富多彩': 7,
#  '为了': 4,
#  '主要': 9,
#  '举一反三': 7,
#  '举足轻重': 7,
#  '之间': 4,
#  '也是': 8,
#  '于是': 6,
#  '五花八门': 6,
#  '产品': 5,
#  '产生': 7,
#  '人们': 7,
#  '人民': 8,
#  '人类': 7,
#  '什么': 6,
#  '今天': 3,
#  '他们': 6,
#  '以及': 24,
#  '以后': 7,
#  '任何': 4,
#  '任务': 7,
#  '任重道远': 7,
#  '企业': 8,
#  '众所周知': 7,
#  '但是': 6,
#  '作为': 12,
#  '作用': 6,
#  '你们': 7,
#  '使用': 6,
#  '例如': 7,
#  '供不应求': 7,
#  '全力以赴': 6,
#  '全国': 8,
#  '全心全意': 6,
#  '关系': 9,
#  '其中': 8,
#  '其他': 8,
#  '具体': 6,
#  '具有': 10,
#  '内容': 7,
#  '决定': 5,
#  '出来': 7,
#  '出现': 6,
#  '分析': 6,
# ...
