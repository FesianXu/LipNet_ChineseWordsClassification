# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import imageio
import cv2
from PIL import Image
# %matplotlib inline

# %%
datatype = ['train', 'test']
load_path= lambda x: '/home/fesian/contest_workspace/chunyu/dataset/landmarks_normal/{}data/'.format(x)
save_path = lambda x: '/home/fesian/contest_workspace/chunyu/dataset/landmark2img/{}/'.format(x)

# %%
links = [
    (48, 49), (49,50), (50,51), (51,52), (52,53), (53,54),(54,55), (55,56), (56,57), (57,58), (58,59), (59,48),
    (48,60),(60,61),(61,62),(62,63),(63,64),(64,54),(60,67),(67,66),(66,65),(65,64),(64,54)
]
links = np.array(links)


for eacht in datatype:
    lists = os.listdir(load_path(eacht))
    for ind, s in enumerate(lists):
        print(' => {} mode, with sample index {}'.format(eacht, ind))
        path = load_path(eacht)+s
        sample = np.load(path)
        if sample.shape[0] == 0:
            continue
        sample = sample[:, 48:68, :]
        nframe, njoint, ndepth = sample.shape
        center = sample[:, 0, :][:,np.newaxis,:]
        sample -= center
        miny = np.min(sample, axis=1)
        miny = miny[:, np.newaxis, :]
        sample -= miny
        save_folder = save_path(eacht)+s[:-4]+'/'
        if not os.path.exists(save_folder):
            os.makedirs(save_folder)
        
        fig = plt.figure()
        for indf, frame in enumerate(sample):
            plt.clf()
            for pair in links:
                p1,p2 = pair[0]-48, pair[1]-48
                plt.plot([frame[p1, 0], frame[p2,0]], [frame[p1, 1], frame[p2,1]], 'r')
            save_filename = save_folder+'{}.png'.format(indf)
            plt.xticks([])  #去掉x轴
            plt.yticks([])  #去掉y轴
            plt.axis('off')  #去掉坐标轴
            plt.savefig(save_filename)
        plt.cla()
        plt.close("all")
#             fig.canvas.draw()
#             # Now we can save it to a numpy array.
#             data = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')
#             data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
#             print(data.shape)
# Out:
#  => train mode, with sample index 0
#  => train mode, with sample index 1
#  => train mode, with sample index 2
#  => train mode, with sample index 3
#  => train mode, with sample index 4
#  => train mode, with sample index 5
#  => train mode, with sample index 6
#  => train mode, with sample index 7
#  => train mode, with sample index 8
#  => train mode, with sample index 9
#  => train mode, with sample index 10
#  => train mode, with sample index 11
#  => train mode, with sample index 12
#  => train mode, with sample index 13
#  => train mode, with sample index 14
#  => train mode, with sample index 15
#  => train mode, with sample index 16
#  => train mode, with sample index 17
#  => train mode, with sample index 18
#  => train mode, with sample index 19
#  => train mode, with sample index 20
#  => train mode, with sample index 21
#  => train mode, with sample index 22
#  => train mode, with sample index 23
#  => train mode, with sample index 24
#  => train mode, with sample index 25
#  => train mode, with sample index 26
#  => train mode, with sample index 27
#  => train mode, with sample index 28
#  => train mode, with sample index 29
#  => train mode, with sample index 30
#  => train mode, with sample index 31
#  => train mode, with sample index 32
#  => train mode, with sample index 33
#  => train mode, with sample index 34
#  => train mode, with sample index 35
#  => train mode, with sample index 36
#  => train mode, with sample index 37
#  => train mode, with sample index 38
#  => train mode, with sample index 39
#  => train mode, with sample index 40
#  => train mode, with sample index 41
#  => train mode, with sample index 42
#  => train mode, with sample index 43
#  => train mode, with sample index 44
#  => train mode, with sample index 45
#  => train mode, with sample index 46
#  => train mode, with sample index 47
#  => train mode, with sample index 48
#  => train mode, with sample index 49
#  => train mode, with sample index 50
#  => train mode, with sample index 51
#  => train mode, with sample index 52
#  => train mode, with sample index 53
#  => train mode, with sample index 54
#  => train mode, with sample index 55
#  => train mode, with sample index 56
#  => train mode, with sample index 57
#  => train mode, with sample index 58
#  => train mode, with sample index 59
#  => train mode, with sample index 60
#  => train mode, with sample index 61
#  => train mode, with sample index 62
#  => train mode, with sample index 63
#  => train mode, with sample index 64
#  => train mode, with sample index 65
#  => train mode, with sample index 66
#  => train mode, with sample index 67
#  => train mode, with sample index 68
#  => train mode, with sample index 69
#  => train mode, with sample index 70
#  => train mode, with sample index 71
#  => train mode, with sample index 72
#  => train mode, with sample index 73
#  => train mode, with sample index 74
#  => train mode, with sample index 75
#  => train mode, with sample index 76
#  => train mode, with sample index 77
#  => train mode, with sample index 78
#  => train mode, with sample index 79
#  => train mode, with sample index 80
#  => train mode, with sample index 81
#  => train mode, with sample index 82
#  => train mode, with sample index 83
#  => train mode, with sample index 84
#  => train mode, with sample index 85
#  => train mode, with sample index 86
#  => train mode, with sample index 87
#  => train mode, with sample index 88
#  => train mode, with sample index 89
#  => train mode, with sample index 90
#  => train mode, with sample index 91
#  => train mode, with sample index 92
#  => train mode, with sample index 93
#  => train mode, with sample index 94
#  => train mode, with sample index 95
#  => train mode, with sample index 96
#  => train mode, with sample index 97
#  => train mode, with sample index 98
#  => train mode, with sample index 99
#  => train mode, with sample index 100
#  => train mode, with sample index 101
#  => train mode, with sample index 102
#  => train mode, with sample index 103
#  => train mode, with sample index 104
#  => train mode, with sample index 105
#  => train mode, with sample index 106
#  => train mode, with sample index 107
#  => train mode, with sample index 108
#  => train mode, with sample index 109
#  => train mode, with sample index 110
#  => train mode, with sample index 111
#  => train mode, with sample index 112
#  => train mode, with sample index 113
#  => train mode, with sample index 114
#  => train mode, with sample index 115
#  => train mode, with sample index 116
#  => train mode, with sample index 117
#  => train mode, with sample index 118
#  => train mode, with sample index 119
#  => train mode, with sample index 120
#  => train mode, with sample index 121
#  => train mode, with sample index 122
#  => train mode, with sample index 123
#  => train mode, with sample index 124
#  => train mode, with sample index 125
#  => train mode, with sample index 126
#  => train mode, with sample index 127
#  => train mode, with sample index 128
#  => train mode, with sample index 129
#  => train mode, with sample index 130
#  => train mode, with sample index 131
#  => train mode, with sample index 132
#  => train mode, with sample index 133
#  => train mode, with sample index 134
#  => train mode, with sample index 135
#  => train mode, with sample index 136
#  => train mode, with sample index 137
#  => train mode, with sample index 138
#  => train mode, with sample index 139
#  => train mode, with sample index 140
#  => train mode, with sample index 141
#  => train mode, with sample index 142
#  => train mode, with sample index 143
#  => train mode, with sample index 144
#  => train mode, with sample index 145
#  => train mode, with sample index 146
#  => train mode, with sample index 147
#  => train mode, with sample index 148
#  => train mode, with sample index 149
#  => train mode, with sample index 150
#  => train mode, with sample index 151
#  => train mode, with sample index 152
#  => train mode, with sample index 153
#  => train mode, with sample index 154
#  => train mode, with sample index 155
#  => train mode, with sample index 156
#  => train mode, with sample index 157
#  => train mode, with sample index 158
#  => train mode, with sample index 159
#  => train mode, with sample index 160
#  => train mode, with sample index 161
#  => train mode, with sample index 162
#  => train mode, with sample index 163
#  => train mode, with sample index 164
#  => train mode, with sample index 165
#  => train mode, with sample index 166
#  => train mode, with sample index 167
#  => train mode, with sample index 168
#  => train mode, with sample index 169
#  => train mode, with sample index 170
#  => train mode, with sample index 171
#  => train mode, with sample index 172
#  => train mode, with sample index 173
#  => train mode, with sample index 174
#  => train mode, with sample index 175
#  => train mode, with sample index 176
#  => train mode, with sample index 177
#  => train mode, with sample index 178
#  => train mode, with sample index 179
#  => train mode, with sample index 180
#  => train mode, with sample index 181
#  => train mode, with sample index 182
#  => train mode, with sample index 183
#  => train mode, with sample index 184
#  => train mode, with sample index 185
#  => train mode, with sample index 186
#  => train mode, with sample index 187
#  => train mode, with sample index 188
#  => train mode, with sample index 189
#  => train mode, with sample index 190
#  => train mode, with sample index 191
#  => train mode, with sample index 192
#  => train mode, with sample index 193
#  => train mode, with sample index 194
#  => train mode, with sample index 195
#  => train mode, with sample index 196
#  => train mode, with sample index 197
#  => train mode, with sample index 198
#  => train mode, with sample index 199
#  => train mode, with sample index 200
#  => train mode, with sample index 201
#  => train mode, with sample index 202
#  => train mode, with sample index 203
#  => train mode, with sample index 204
#  => train mode, with sample index 205
#  => train mode, with sample index 206
#  => train mode, with sample index 207
#  => train mode, with sample index 208
#  => train mode, with sample index 209
#  => train mode, with sample index 210
#  => train mode, with sample index 211
#  => train mode, with sample index 212
#  => train mode, with sample index 213
#  => train mode, with sample index 214
#  => train mode, with sample index 215
#  => train mode, with sample index 216
#  => train mode, with sample index 217
#  => train mode, with sample index 218
#  => train mode, with sample index 219
#  => train mode, with sample index 220
#  => train mode, with sample index 221
#  => train mode, with sample index 222
#  => train mode, with sample index 223
#  => train mode, with sample index 224
#  => train mode, with sample index 225
#  => train mode, with sample index 226
#  => train mode, with sample index 227
#  => train mode, with sample index 228
#  => train mode, with sample index 229
#  => train mode, with sample index 230
#  => train mode, with sample index 231
#  => train mode, with sample index 232
#  => train mode, with sample index 233
#  => train mode, with sample index 234
#  => train mode, with sample index 235
#  => train mode, with sample index 236
#  => train mode, with sample index 237
#  => train mode, with sample index 238
#  => train mode, with sample index 239
#  => train mode, with sample index 240
#  => train mode, with sample index 241
#  => train mode, with sample index 242
#  => train mode, with sample index 243
#  => train mode, with sample index 244
#  => train mode, with sample index 245
#  => train mode, with sample index 246
#  => train mode, with sample index 247
#  => train mode, with sample index 248
#  => train mode, with sample index 249
#  => train mode, with sample index 250
#  => train mode, with sample index 251
#  => train mode, with sample index 252
#  => train mode, with sample index 253
#  => train mode, with sample index 254
#  => train mode, with sample index 255
#  => train mode, with sample index 256
#  => train mode, with sample index 257
#  => train mode, with sample index 258
#  => train mode, with sample index 259
#  => train mode, with sample index 260
#  => train mode, with sample index 261
#  => train mode, with sample index 262
#  => train mode, with sample index 263
#  => train mode, with sample index 264
#  => train mode, with sample index 265
#  => train mode, with sample index 266
#  => train mode, with sample index 267
#  => train mode, with sample index 268
#  => train mode, with sample index 269
#  => train mode, with sample index 270
#  => train mode, with sample index 271
#  => train mode, with sample index 272
#  => train mode, with sample index 273
#  => train mode, with sample index 274
#  => train mode, with sample index 275
#  => train mode, with sample index 276
#  => train mode, with sample index 277
#  => train mode, with sample index 278
#  => train mode, with sample index 279
#  => train mode, with sample index 280
#  => train mode, with sample index 281
#  => train mode, with sample index 282
#  => train mode, with sample index 283
#  => train mode, with sample index 284
#  => train mode, with sample index 285
#  => train mode, with sample index 286
#  => train mode, with sample index 287
#  => train mode, with sample index 288
#  => train mode, with sample index 289
#  => train mode, with sample index 290
#  => train mode, with sample index 291
#  => train mode, with sample index 292
#  => train mode, with sample index 293
#  => train mode, with sample index 294
#  => train mode, with sample index 295
#  => train mode, with sample index 296
#  => train mode, with sample index 297
#  => train mode, with sample index 298
#  => train mode, with sample index 299
#  => train mode, with sample index 300
#  => train mode, with sample index 301
#  => train mode, with sample index 302
#  => train mode, with sample index 303
#  => train mode, with sample index 304
#  => train mode, with sample index 305
#  => train mode, with sample index 306
#  => train mode, with sample index 307
#  => train mode, with sample index 308
#  => train mode, with sample index 309
#  => train mode, with sample index 310
#  => train mode, with sample index 311
#  => train mode, with sample index 312
#  => train mode, with sample index 313
#  => train mode, with sample index 314
#  => train mode, with sample index 315
#  => train mode, with sample index 316
#  => train mode, with sample index 317
#  => train mode, with sample index 318
#  => train mode, with sample index 319
#  => train mode, with sample index 320
#  => train mode, with sample index 321
#  => train mode, with sample index 322
#  => train mode, with sample index 323
#  => train mode, with sample index 324
#  => train mode, with sample index 325
#  => train mode, with sample index 326
#  => train mode, with sample index 327
#  => train mode, with sample index 328
#  => train mode, with sample index 329
#  => train mode, with sample index 330
#  => train mode, with sample index 331
#  => train mode, with sample index 332
#  => train mode, with sample index 333
#  => train mode, with sample index 334
#  => train mode, with sample index 335
#  => train mode, with sample index 336
#  => train mode, with sample index 337
#  => train mode, with sample index 338
#  => train mode, with sample index 339
#  => train mode, with sample index 340
#  => train mode, with sample index 341
#  => train mode, with sample index 342
#  => train mode, with sample index 343
#  => train mode, with sample index 344
#  => train mode, with sample index 345
#  => train mode, with sample index 346
#  => train mode, with sample index 347
#  => train mode, with sample index 348
#  => train mode, with sample index 349
#  => train mode, with sample index 350
#  => train mode, with sample index 351
#  => train mode, with sample index 352
#  => train mode, with sample index 353
#  => train mode, with sample index 354
#  => train mode, with sample index 355
#  => train mode, with sample index 356
#  => train mode, with sample index 357
#  => train mode, with sample index 358
#  => train mode, with sample index 359
#  => train mode, with sample index 360
#  => train mode, with sample index 361
#  => train mode, with sample index 362
#  => train mode, with sample index 363
#  => train mode, with sample index 364
#  => train mode, with sample index 365
#  => train mode, with sample index 366
#  => train mode, with sample index 367
#  => train mode, with sample index 368
#  => train mode, with sample index 369
#  => train mode, with sample index 370
#  => train mode, with sample index 371
#  => train mode, with sample index 372
#  => train mode, with sample index 373
#  => train mode, with sample index 374
#  => train mode, with sample index 375
#  => train mode, with sample index 376
#  => train mode, with sample index 377
#  => train mode, with sample index 378
#  => train mode, with sample index 379
#  => train mode, with sample index 380
#  => train mode, with sample index 381
#  => train mode, with sample index 382
#  => train mode, with sample index 383
#  => train mode, with sample index 384
#  => train mode, with sample index 385
#  => train mode, with sample index 386
#  => train mode, with sample index 387
#  => train mode, with sample index 388
#  => train mode, with sample index 389
#  => train mode, with sample index 390
#  => train mode, with sample index 391
#  => train mode, with sample index 392
#  => train mode, with sample index 393
#  => train mode, with sample index 394
#  => train mode, with sample index 395
#  => train mode, with sample index 396
#  => train mode, with sample index 397
#  => train mode, with sample index 398
#  => train mode, with sample index 399
#  => train mode, with sample index 400
#  => train mode, with sample index 401
#  => train mode, with sample index 402
#  => train mode, with sample index 403
#  => train mode, with sample index 404
#  => train mode, with sample index 405
#  => train mode, with sample index 406
#  => train mode, with sample index 407
#  => train mode, with sample index 408
#  => train mode, with sample index 409
#  => train mode, with sample index 410
#  => train mode, with sample index 411
#  => train mode, with sample index 412
#  => train mode, with sample index 413
#  => train mode, with sample index 414
#  => train mode, with sample index 415
#  => train mode, with sample index 416
#  => train mode, with sample index 417
#  => train mode, with sample index 418
#  => train mode, with sample index 419
#  => train mode, with sample index 420
#  => train mode, with sample index 421
#  => train mode, with sample index 422
#  => train mode, with sample index 423
#  => train mode, with sample index 424
#  => train mode, with sample index 425
#  => train mode, with sample index 426
#  => train mode, with sample index 427
#  => train mode, with sample index 428
#  => train mode, with sample index 429
#  => train mode, with sample index 430
#  => train mode, with sample index 431
#  => train mode, with sample index 432
#  => train mode, with sample index 433
#  => train mode, with sample index 434
#  => train mode, with sample index 435
#  => train mode, with sample index 436
#  => train mode, with sample index 437
#  => train mode, with sample index 438
#  => train mode, with sample index 439
#  => train mode, with sample index 440
#  => train mode, with sample index 441
#  => train mode, with sample index 442
#  => train mode, with sample index 443
#  => train mode, with sample index 444
#  => train mode, with sample index 445
#  => train mode, with sample index 446
#  => train mode, with sample index 447
#  => train mode, with sample index 448
#  => train mode, with sample index 449
#  => train mode, with sample index 450
#  => train mode, with sample index 451
#  => train mode, with sample index 452
#  => train mode, with sample index 453
#  => train mode, with sample index 454
#  => train mode, with sample index 455
#  => train mode, with sample index 456
#  => train mode, with sample index 457
#  => train mode, with sample index 458
#  => train mode, with sample index 459
#  => train mode, with sample index 460
#  => train mode, with sample index 461
#  => train mode, with sample index 462
#  => train mode, with sample index 463
#  => train mode, with sample index 464
#  => train mode, with sample index 465
#  => train mode, with sample index 466
#  => train mode, with sample index 467
#  => train mode, with sample index 468
#  => train mode, with sample index 469
#  => train mode, with sample index 470
#  => train mode, with sample index 471
#  => train mode, with sample index 472
#  => train mode, with sample index 473
#  => train mode, with sample index 474
#  => train mode, with sample index 475
#  => train mode, with sample index 476
#  => train mode, with sample index 477
#  => train mode, with sample index 478
#  => train mode, with sample index 479
#  => train mode, with sample index 480
#  => train mode, with sample index 481
#  => train mode, with sample index 482
#  => train mode, with sample index 483
#  => train mode, with sample index 484
#  => train mode, with sample index 485
#  => train mode, with sample index 486
#  => train mode, with sample index 487
#  => train mode, with sample index 488
#  => train mode, with sample index 489
#  => train mode, with sample index 490
#  => train mode, with sample index 491
#  => train mode, with sample index 492
#  => train mode, with sample index 493
#  => train mode, with sample index 494
#  => train mode, with sample index 495
#  => train mode, with sample index 496
#  => train mode, with sample index 497
#  => train mode, with sample index 498
#  => train mode, with sample index 499
#  => train mode, with sample index 500
#  => train mode, with sample index 501
#  => train mode, with sample index 502
#  => train mode, with sample index 503
#  => train mode, with sample index 504
#  => train mode, with sample index 505
#  => train mode, with sample index 506
#  => train mode, with sample index 507
#  => train mode, with sample index 508
#  => train mode, with sample index 509
#  => train mode, with sample index 510
#  => train mode, with sample index 511
#  => train mode, with sample index 512
#  => train mode, with sample index 513
#  => train mode, with sample index 514
#  => train mode, with sample index 515
#  => train mode, with sample index 516
#  => train mode, with sample index 517
#  => train mode, with sample index 518
#  => train mode, with sample index 519
#  => train mode, with sample index 520
#  => train mode, with sample index 521
#  => train mode, with sample index 522
#  => train mode, with sample index 523
#  => train mode, with sample index 524
#  => train mode, with sample index 525
#  => train mode, with sample index 526
#  => train mode, with sample index 527
#  => train mode, with sample index 528
#  => train mode, with sample index 529
#  => train mode, with sample index 530
#  => train mode, with sample index 531
#  => train mode, with sample index 532
#  => train mode, with sample index 533
#  => train mode, with sample index 534
#  => train mode, with sample index 535
#  => train mode, with sample index 536
#  => train mode, with sample index 537
#  => train mode, with sample index 538
#  => train mode, with sample index 539
#  => train mode, with sample index 540
#  => train mode, with sample index 541
#  => train mode, with sample index 542
#  => train mode, with sample index 543
#  => train mode, with sample index 544
#  => train mode, with sample index 545
#  => train mode, with sample index 546
#  => train mode, with sample index 547
#  => train mode, with sample index 548
#  => train mode, with sample index 549
#  => train mode, with sample index 550
#  => train mode, with sample index 551
#  => train mode, with sample index 552
#  => train mode, with sample index 553
#  => train mode, with sample index 554
#  => train mode, with sample index 555
#  => train mode, with sample index 556
#  => train mode, with sample index 557
#  => train mode, with sample index 558
#  => train mode, with sample index 559
#  => train mode, with sample index 560
#  => train mode, with sample index 561
#  => train mode, with sample index 562
#  => train mode, with sample index 563
#  => train mode, with sample index 564
#  => train mode, with sample index 565
#  => train mode, with sample index 566
#  => train mode, with sample index 567
#  => train mode, with sample index 568
#  => train mode, with sample index 569
#  => train mode, with sample index 570
#  => train mode, with sample index 571
#  => train mode, with sample index 572
#  => train mode, with sample index 573
#  => train mode, with sample index 574
#  => train mode, with sample index 575
#  => train mode, with sample index 576
#  => train mode, with sample index 577
#  => train mode, with sample index 578
#  => train mode, with sample index 579
#  => train mode, with sample index 580
#  => train mode, with sample index 581
#  => train mode, with sample index 582
#  => train mode, with sample index 583
#  => train mode, with sample index 584
#  => train mode, with sample index 585
#  => train mode, with sample index 586
#  => train mode, with sample index 587
#  => train mode, with sample index 588
#  => train mode, with sample index 589
#  => train mode, with sample index 590
#  => train mode, with sample index 591
#  => train mode, with sample index 592
#  => train mode, with sample index 593
#  => train mode, with sample index 594
#  => train mode, with sample index 595
#  => train mode, with sample index 596
#  => train mode, with sample index 597
#  => train mode, with sample index 598
#  => train mode, with sample index 599
#  => train mode, with sample index 600
#  => train mode, with sample index 601
#  => train mode, with sample index 602
#  => train mode, with sample index 603
#  => train mode, with sample index 604
#  => train mode, with sample index 605
#  => train mode, with sample index 606
#  => train mode, with sample index 607
#  => train mode, with sample index 608
#  => train mode, with sample index 609
#  => train mode, with sample index 610
#  => train mode, with sample index 611
#  => train mode, with sample index 612
#  => train mode, with sample index 613
#  => train mode, with sample index 614
#  => train mode, with sample index 615
#  => train mode, with sample index 616
#  => train mode, with sample index 617
#  => train mode, with sample index 618
#  => train mode, with sample index 619
#  => train mode, with sample index 620
#  => train mode, with sample index 621
#  => train mode, with sample index 622
#  => train mode, with sample index 623
#  => train mode, with sample index 624
#  => train mode, with sample index 625
#  => train mode, with sample index 626
#  => train mode, with sample index 627
#  => train mode, with sample index 628
#  => train mode, with sample index 629
#  => train mode, with sample index 630
#  => train mode, with sample index 631
#  => train mode, with sample index 632
#  => train mode, with sample index 633
#  => train mode, with sample index 634
#  => train mode, with sample index 635
#  => train mode, with sample index 636
#  => train mode, with sample index 637
#  => train mode, with sample index 638
#  => train mode, with sample index 639
#  => train mode, with sample index 640
#  => train mode, with sample index 641
#  => train mode, with sample index 642
#  => train mode, with sample index 643
#  => train mode, with sample index 644
#  => train mode, with sample index 645
#  => train mode, with sample index 646
#  => train mode, with sample index 647
#  => train mode, with sample index 648
#  => train mode, with sample index 649
#  => train mode, with sample index 650
#  => train mode, with sample index 651
#  => train mode, with sample index 652
#  => train mode, with sample index 653
#  => train mode, with sample index 654
#  => train mode, with sample index 655
#  => train mode, with sample index 656
#  => train mode, with sample index 657
#  => train mode, with sample index 658
#  => train mode, with sample index 659
#  => train mode, with sample index 660
#  => train mode, with sample index 661
#  => train mode, with sample index 662
#  => train mode, with sample index 663
#  => train mode, with sample index 664
#  => train mode, with sample index 665
#  => train mode, with sample index 666
#  => train mode, with sample index 667
#  => train mode, with sample index 668
#  => train mode, with sample index 669
#  => train mode, with sample index 670
#  => train mode, with sample index 671
#  => train mode, with sample index 672
#  => train mode, with sample index 673
#  => train mode, with sample index 674
#  => train mode, with sample index 675
#  => train mode, with sample index 676
