# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import imageio
import cv2
from PIL import Image
# %matplotlib inline

# %%
datatype = ['test']
load_path= lambda x: '/home/fesian/contest_workspace/chunyu/dataset/landmarks_normal/{}data/'.format(x)
save_path = lambda x: '/home/fesian/contest_workspace/chunyu/dataset/landmark2img/{}/'.format(x)

# %%
links = [
    (48, 49), (49,50), (50,51), (51,52), (52,53), (53,54),(54,55), (55,56), (56,57), (57,58), (58,59), (59,48),
    (48,60),(60,61),(61,62),(62,63),(63,64),(64,54),(60,67),(67,66),(66,65),(65,64),(64,54)
]
links = np.array(links)


for eacht in datatype:
    lists = os.listdir(load_path(eacht))
    for ind, s in enumerate(lists):
        print(' => {} mode, with sample index {}'.format(eacht, ind))
        path = load_path(eacht)+s
        sample = np.load(path)
        if sample.shape[0] == 0:
            continue
        sample = sample[:, 48:68, :]
        nframe, njoint, ndepth = sample.shape
        center = sample[:, 0, :][:,np.newaxis,:]
        sample -= center
        miny = np.min(sample, axis=1)
        miny = miny[:, np.newaxis, :]
        sample -= miny
        save_folder = save_path(eacht)+s[:-4]+'/'
        if not os.path.exists(save_folder):
            os.makedirs(save_folder)
        
        fig = plt.figure()
        for indf, frame in enumerate(sample):
            plt.clf()
            for pair in links:
                p1,p2 = pair[0]-48, pair[1]-48
                plt.plot([frame[p1, 0], frame[p2,0]], [frame[p1, 1], frame[p2,1]], 'r')
            save_filename = save_folder+'{}.png'.format(indf)
            plt.xticks([])  #去掉x轴
            plt.yticks([])  #去掉y轴
            plt.axis('off')  #去掉坐标轴
            plt.savefig(save_filename)
        plt.cla()
        plt.close("all")
#             fig.canvas.draw()
#             # Now we can save it to a numpy array.
#             data = np.fromstring(fig.canvas.tostring_rgb(), dtype=np.uint8, sep='')
#             data = data.reshape(fig.canvas.get_width_height()[::-1] + (3,))
#             print(data.shape)
# Out:
#  => test mode, with sample index 0
#  => test mode, with sample index 1
#  => test mode, with sample index 2
#  => test mode, with sample index 3
#  => test mode, with sample index 4
#  => test mode, with sample index 5
#  => test mode, with sample index 6
#  => test mode, with sample index 7
#  => test mode, with sample index 8
#  => test mode, with sample index 9
#  => test mode, with sample index 10
#  => test mode, with sample index 11
#  => test mode, with sample index 12
#  => test mode, with sample index 13
#  => test mode, with sample index 14
#  => test mode, with sample index 15
#  => test mode, with sample index 16
#  => test mode, with sample index 17
#  => test mode, with sample index 18
#  => test mode, with sample index 19
#  => test mode, with sample index 20
#  => test mode, with sample index 21
#  => test mode, with sample index 22
#  => test mode, with sample index 23
#  => test mode, with sample index 24
#  => test mode, with sample index 25
#  => test mode, with sample index 26
#  => test mode, with sample index 27
#  => test mode, with sample index 28
#  => test mode, with sample index 29
#  => test mode, with sample index 30
#  => test mode, with sample index 31
#  => test mode, with sample index 32
#  => test mode, with sample index 33
#  => test mode, with sample index 34
#  => test mode, with sample index 35
#  => test mode, with sample index 36
#  => test mode, with sample index 37
#  => test mode, with sample index 38
#  => test mode, with sample index 39
#  => test mode, with sample index 40
#  => test mode, with sample index 41
#  => test mode, with sample index 42
#  => test mode, with sample index 43
#  => test mode, with sample index 44
#  => test mode, with sample index 45
#  => test mode, with sample index 46
#  => test mode, with sample index 47
#  => test mode, with sample index 48
#  => test mode, with sample index 49
#  => test mode, with sample index 50
#  => test mode, with sample index 51
#  => test mode, with sample index 52
#  => test mode, with sample index 53
#  => test mode, with sample index 54
#  => test mode, with sample index 55
#  => test mode, with sample index 56
#  => test mode, with sample index 57
#  => test mode, with sample index 58
#  => test mode, with sample index 59
#  => test mode, with sample index 60
#  => test mode, with sample index 61
#  => test mode, with sample index 62
#  => test mode, with sample index 63
#  => test mode, with sample index 64
#  => test mode, with sample index 65
#  => test mode, with sample index 66
#  => test mode, with sample index 67
#  => test mode, with sample index 68
#  => test mode, with sample index 69
#  => test mode, with sample index 70
#  => test mode, with sample index 71
#  => test mode, with sample index 72
#  => test mode, with sample index 73
#  => test mode, with sample index 74
#  => test mode, with sample index 75
#  => test mode, with sample index 76
#  => test mode, with sample index 77
#  => test mode, with sample index 78
#  => test mode, with sample index 79
#  => test mode, with sample index 80
#  => test mode, with sample index 81
#  => test mode, with sample index 82
#  => test mode, with sample index 83
#  => test mode, with sample index 84
#  => test mode, with sample index 85
#  => test mode, with sample index 86
#  => test mode, with sample index 87
#  => test mode, with sample index 88
#  => test mode, with sample index 89
#  => test mode, with sample index 90
#  => test mode, with sample index 91
#  => test mode, with sample index 92
#  => test mode, with sample index 93
#  => test mode, with sample index 94
#  => test mode, with sample index 95
#  => test mode, with sample index 96
#  => test mode, with sample index 97
#  => test mode, with sample index 98
#  => test mode, with sample index 99
#  => test mode, with sample index 100
#  => test mode, with sample index 101
#  => test mode, with sample index 102
#  => test mode, with sample index 103
#  => test mode, with sample index 104
#  => test mode, with sample index 105
#  => test mode, with sample index 106
#  => test mode, with sample index 107
#  => test mode, with sample index 108
#  => test mode, with sample index 109
#  => test mode, with sample index 110
#  => test mode, with sample index 111
#  => test mode, with sample index 112
#  => test mode, with sample index 113
#  => test mode, with sample index 114
#  => test mode, with sample index 115
#  => test mode, with sample index 116
#  => test mode, with sample index 117
#  => test mode, with sample index 118
#  => test mode, with sample index 119
#  => test mode, with sample index 120
#  => test mode, with sample index 121
#  => test mode, with sample index 122
#  => test mode, with sample index 123
#  => test mode, with sample index 124
#  => test mode, with sample index 125
#  => test mode, with sample index 126
#  => test mode, with sample index 127
#  => test mode, with sample index 128
#  => test mode, with sample index 129
#  => test mode, with sample index 130
#  => test mode, with sample index 131
#  => test mode, with sample index 132
#  => test mode, with sample index 133
#  => test mode, with sample index 134
#  => test mode, with sample index 135
#  => test mode, with sample index 136
#  => test mode, with sample index 137
#  => test mode, with sample index 138
#  => test mode, with sample index 139
#  => test mode, with sample index 140
#  => test mode, with sample index 141
#  => test mode, with sample index 142
#  => test mode, with sample index 143
#  => test mode, with sample index 144
#  => test mode, with sample index 145
#  => test mode, with sample index 146
#  => test mode, with sample index 147
#  => test mode, with sample index 148
#  => test mode, with sample index 149
#  => test mode, with sample index 150
#  => test mode, with sample index 151
#  => test mode, with sample index 152
#  => test mode, with sample index 153
#  => test mode, with sample index 154
#  => test mode, with sample index 155
#  => test mode, with sample index 156
#  => test mode, with sample index 157
#  => test mode, with sample index 158
#  => test mode, with sample index 159
#  => test mode, with sample index 160
#  => test mode, with sample index 161
#  => test mode, with sample index 162
#  => test mode, with sample index 163
#  => test mode, with sample index 164
#  => test mode, with sample index 165
#  => test mode, with sample index 166
#  => test mode, with sample index 167
#  => test mode, with sample index 168
#  => test mode, with sample index 169
#  => test mode, with sample index 170
#  => test mode, with sample index 171
#  => test mode, with sample index 172
#  => test mode, with sample index 173
#  => test mode, with sample index 174
#  => test mode, with sample index 175
#  => test mode, with sample index 176
#  => test mode, with sample index 177
#  => test mode, with sample index 178
#  => test mode, with sample index 179
#  => test mode, with sample index 180
#  => test mode, with sample index 181
#  => test mode, with sample index 182
#  => test mode, with sample index 183
#  => test mode, with sample index 184
#  => test mode, with sample index 185
#  => test mode, with sample index 186
#  => test mode, with sample index 187
#  => test mode, with sample index 188
#  => test mode, with sample index 189
#  => test mode, with sample index 190
#  => test mode, with sample index 191
#  => test mode, with sample index 192
#  => test mode, with sample index 193
#  => test mode, with sample index 194
#  => test mode, with sample index 195
#  => test mode, with sample index 196
#  => test mode, with sample index 197
#  => test mode, with sample index 198
#  => test mode, with sample index 199
#  => test mode, with sample index 200
#  => test mode, with sample index 201
#  => test mode, with sample index 202
#  => test mode, with sample index 203
#  => test mode, with sample index 204
#  => test mode, with sample index 205
#  => test mode, with sample index 206
#  => test mode, with sample index 207
#  => test mode, with sample index 208
#  => test mode, with sample index 209
#  => test mode, with sample index 210
#  => test mode, with sample index 211
#  => test mode, with sample index 212
#  => test mode, with sample index 213
#  => test mode, with sample index 214
#  => test mode, with sample index 215
#  => test mode, with sample index 216
#  => test mode, with sample index 217
#  => test mode, with sample index 218
#  => test mode, with sample index 219
#  => test mode, with sample index 220
#  => test mode, with sample index 221
#  => test mode, with sample index 222
#  => test mode, with sample index 223
#  => test mode, with sample index 224
#  => test mode, with sample index 225
#  => test mode, with sample index 226
#  => test mode, with sample index 227
#  => test mode, with sample index 228
#  => test mode, with sample index 229
#  => test mode, with sample index 230
#  => test mode, with sample index 231
#  => test mode, with sample index 232
#  => test mode, with sample index 233
#  => test mode, with sample index 234
#  => test mode, with sample index 235
#  => test mode, with sample index 236
#  => test mode, with sample index 237
#  => test mode, with sample index 238
#  => test mode, with sample index 239
#  => test mode, with sample index 240
#  => test mode, with sample index 241
#  => test mode, with sample index 242
#  => test mode, with sample index 243
#  => test mode, with sample index 244
#  => test mode, with sample index 245
#  => test mode, with sample index 246
#  => test mode, with sample index 247
#  => test mode, with sample index 248
#  => test mode, with sample index 249
#  => test mode, with sample index 250
#  => test mode, with sample index 251
#  => test mode, with sample index 252
#  => test mode, with sample index 253
#  => test mode, with sample index 254
#  => test mode, with sample index 255
#  => test mode, with sample index 256
#  => test mode, with sample index 257
#  => test mode, with sample index 258
#  => test mode, with sample index 259
#  => test mode, with sample index 260
#  => test mode, with sample index 261
#  => test mode, with sample index 262
#  => test mode, with sample index 263
#  => test mode, with sample index 264
#  => test mode, with sample index 265
#  => test mode, with sample index 266
#  => test mode, with sample index 267
#  => test mode, with sample index 268
#  => test mode, with sample index 269
#  => test mode, with sample index 270
#  => test mode, with sample index 271
#  => test mode, with sample index 272
#  => test mode, with sample index 273
#  => test mode, with sample index 274
#  => test mode, with sample index 275
#  => test mode, with sample index 276
#  => test mode, with sample index 277
#  => test mode, with sample index 278
#  => test mode, with sample index 279
#  => test mode, with sample index 280
#  => test mode, with sample index 281
#  => test mode, with sample index 282
#  => test mode, with sample index 283
#  => test mode, with sample index 284
#  => test mode, with sample index 285
#  => test mode, with sample index 286
#  => test mode, with sample index 287
#  => test mode, with sample index 288
#  => test mode, with sample index 289
#  => test mode, with sample index 290
#  => test mode, with sample index 291
#  => test mode, with sample index 292
#  => test mode, with sample index 293
#  => test mode, with sample index 294
#  => test mode, with sample index 295
#  => test mode, with sample index 296
#  => test mode, with sample index 297
#  => test mode, with sample index 298
#  => test mode, with sample index 299
#  => test mode, with sample index 300
#  => test mode, with sample index 301
#  => test mode, with sample index 302
#  => test mode, with sample index 303
#  => test mode, with sample index 304
#  => test mode, with sample index 305
#  => test mode, with sample index 306
#  => test mode, with sample index 307
#  => test mode, with sample index 308
#  => test mode, with sample index 309
#  => test mode, with sample index 310
#  => test mode, with sample index 311
#  => test mode, with sample index 312
#  => test mode, with sample index 313
#  => test mode, with sample index 314
#  => test mode, with sample index 315
#  => test mode, with sample index 316
#  => test mode, with sample index 317
#  => test mode, with sample index 318
#  => test mode, with sample index 319
#  => test mode, with sample index 320
#  => test mode, with sample index 321
#  => test mode, with sample index 322
#  => test mode, with sample index 323
#  => test mode, with sample index 324
#  => test mode, with sample index 325
#  => test mode, with sample index 326
#  => test mode, with sample index 327
#  => test mode, with sample index 328
#  => test mode, with sample index 329
#  => test mode, with sample index 330
#  => test mode, with sample index 331
#  => test mode, with sample index 332
#  => test mode, with sample index 333
#  => test mode, with sample index 334
#  => test mode, with sample index 335
#  => test mode, with sample index 336
#  => test mode, with sample index 337
#  => test mode, with sample index 338
#  => test mode, with sample index 339
#  => test mode, with sample index 340
#  => test mode, with sample index 341
#  => test mode, with sample index 342
#  => test mode, with sample index 343
#  => test mode, with sample index 344
#  => test mode, with sample index 345
#  => test mode, with sample index 346
#  => test mode, with sample index 347
#  => test mode, with sample index 348
#  => test mode, with sample index 349
#  => test mode, with sample index 350
#  => test mode, with sample index 351
#  => test mode, with sample index 352
#  => test mode, with sample index 353
#  => test mode, with sample index 354
#  => test mode, with sample index 355
#  => test mode, with sample index 356
#  => test mode, with sample index 357
#  => test mode, with sample index 358
#  => test mode, with sample index 359
#  => test mode, with sample index 360
#  => test mode, with sample index 361
#  => test mode, with sample index 362
#  => test mode, with sample index 363
#  => test mode, with sample index 364
#  => test mode, with sample index 365
#  => test mode, with sample index 366
#  => test mode, with sample index 367
#  => test mode, with sample index 368
#  => test mode, with sample index 369
#  => test mode, with sample index 370
#  => test mode, with sample index 371
#  => test mode, with sample index 372
#  => test mode, with sample index 373
#  => test mode, with sample index 374
#  => test mode, with sample index 375
#  => test mode, with sample index 376
#  => test mode, with sample index 377
#  => test mode, with sample index 378
#  => test mode, with sample index 379
#  => test mode, with sample index 380
#  => test mode, with sample index 381
#  => test mode, with sample index 382
#  => test mode, with sample index 383
#  => test mode, with sample index 384
#  => test mode, with sample index 385
#  => test mode, with sample index 386
#  => test mode, with sample index 387
#  => test mode, with sample index 388
#  => test mode, with sample index 389
#  => test mode, with sample index 390
#  => test mode, with sample index 391
#  => test mode, with sample index 392
#  => test mode, with sample index 393
#  => test mode, with sample index 394
#  => test mode, with sample index 395
#  => test mode, with sample index 396
#  => test mode, with sample index 397
#  => test mode, with sample index 398
#  => test mode, with sample index 399
#  => test mode, with sample index 400
#  => test mode, with sample index 401
#  => test mode, with sample index 402
#  => test mode, with sample index 403
#  => test mode, with sample index 404
#  => test mode, with sample index 405
#  => test mode, with sample index 406
#  => test mode, with sample index 407
#  => test mode, with sample index 408
#  => test mode, with sample index 409
#  => test mode, with sample index 410
#  => test mode, with sample index 411
#  => test mode, with sample index 412
#  => test mode, with sample index 413
#  => test mode, with sample index 414
#  => test mode, with sample index 415
#  => test mode, with sample index 416
#  => test mode, with sample index 417
#  => test mode, with sample index 418
#  => test mode, with sample index 419
#  => test mode, with sample index 420
#  => test mode, with sample index 421
#  => test mode, with sample index 422
#  => test mode, with sample index 423
#  => test mode, with sample index 424
#  => test mode, with sample index 425
#  => test mode, with sample index 426
#  => test mode, with sample index 427
#  => test mode, with sample index 428
#  => test mode, with sample index 429
#  => test mode, with sample index 430
#  => test mode, with sample index 431
#  => test mode, with sample index 432
#  => test mode, with sample index 433
#  => test mode, with sample index 434
#  => test mode, with sample index 435
#  => test mode, with sample index 436
#  => test mode, with sample index 437
#  => test mode, with sample index 438
#  => test mode, with sample index 439
#  => test mode, with sample index 440
#  => test mode, with sample index 441
#  => test mode, with sample index 442
#  => test mode, with sample index 443
#  => test mode, with sample index 444
#  => test mode, with sample index 445
#  => test mode, with sample index 446
#  => test mode, with sample index 447
#  => test mode, with sample index 448
#  => test mode, with sample index 449
#  => test mode, with sample index 450
#  => test mode, with sample index 451
#  => test mode, with sample index 452
#  => test mode, with sample index 453
#  => test mode, with sample index 454
#  => test mode, with sample index 455
#  => test mode, with sample index 456
#  => test mode, with sample index 457
#  => test mode, with sample index 458
#  => test mode, with sample index 459
#  => test mode, with sample index 460
#  => test mode, with sample index 461
#  => test mode, with sample index 462
#  => test mode, with sample index 463
#  => test mode, with sample index 464
#  => test mode, with sample index 465
#  => test mode, with sample index 466
#  => test mode, with sample index 467
#  => test mode, with sample index 468
#  => test mode, with sample index 469
#  => test mode, with sample index 470
#  => test mode, with sample index 471
#  => test mode, with sample index 472
#  => test mode, with sample index 473
#  => test mode, with sample index 474
#  => test mode, with sample index 475
#  => test mode, with sample index 476
#  => test mode, with sample index 477
#  => test mode, with sample index 478
#  => test mode, with sample index 479
#  => test mode, with sample index 480
#  => test mode, with sample index 481
#  => test mode, with sample index 482
#  => test mode, with sample index 483
#  => test mode, with sample index 484
#  => test mode, with sample index 485
#  => test mode, with sample index 486
#  => test mode, with sample index 487
#  => test mode, with sample index 488
#  => test mode, with sample index 489
#  => test mode, with sample index 490
#  => test mode, with sample index 491
#  => test mode, with sample index 492
#  => test mode, with sample index 493
#  => test mode, with sample index 494
#  => test mode, with sample index 495
#  => test mode, with sample index 496
#  => test mode, with sample index 497
#  => test mode, with sample index 498
#  => test mode, with sample index 499
#  => test mode, with sample index 500
#  => test mode, with sample index 501
#  => test mode, with sample index 502
#  => test mode, with sample index 503
#  => test mode, with sample index 504
#  => test mode, with sample index 505
#  => test mode, with sample index 506
#  => test mode, with sample index 507
#  => test mode, with sample index 508
#  => test mode, with sample index 509
#  => test mode, with sample index 510
#  => test mode, with sample index 511
#  => test mode, with sample index 512
#  => test mode, with sample index 513
#  => test mode, with sample index 514
#  => test mode, with sample index 515
#  => test mode, with sample index 516
#  => test mode, with sample index 517
#  => test mode, with sample index 518
#  => test mode, with sample index 519
#  => test mode, with sample index 520
#  => test mode, with sample index 521
#  => test mode, with sample index 522
#  => test mode, with sample index 523
#  => test mode, with sample index 524
#  => test mode, with sample index 525
#  => test mode, with sample index 526
#  => test mode, with sample index 527
#  => test mode, with sample index 528
#  => test mode, with sample index 529
#  => test mode, with sample index 530
#  => test mode, with sample index 531
#  => test mode, with sample index 532
#  => test mode, with sample index 533
#  => test mode, with sample index 534
#  => test mode, with sample index 535
#  => test mode, with sample index 536
#  => test mode, with sample index 537
#  => test mode, with sample index 538
#  => test mode, with sample index 539
#  => test mode, with sample index 540
#  => test mode, with sample index 541
#  => test mode, with sample index 542
#  => test mode, with sample index 543
#  => test mode, with sample index 544
#  => test mode, with sample index 545
#  => test mode, with sample index 546
#  => test mode, with sample index 547
#  => test mode, with sample index 548
#  => test mode, with sample index 549
#  => test mode, with sample index 550
#  => test mode, with sample index 551
#  => test mode, with sample index 552
#  => test mode, with sample index 553
#  => test mode, with sample index 554
#  => test mode, with sample index 555
#  => test mode, with sample index 556
#  => test mode, with sample index 557
#  => test mode, with sample index 558
#  => test mode, with sample index 559
#  => test mode, with sample index 560
#  => test mode, with sample index 561
#  => test mode, with sample index 562
#  => test mode, with sample index 563
#  => test mode, with sample index 564
#  => test mode, with sample index 565
#  => test mode, with sample index 566
#  => test mode, with sample index 567
#  => test mode, with sample index 568
#  => test mode, with sample index 569
#  => test mode, with sample index 570
#  => test mode, with sample index 571
#  => test mode, with sample index 572
#  => test mode, with sample index 573
#  => test mode, with sample index 574
#  => test mode, with sample index 575
#  => test mode, with sample index 576
#  => test mode, with sample index 577
#  => test mode, with sample index 578
#  => test mode, with sample index 579
#  => test mode, with sample index 580
#  => test mode, with sample index 581
#  => test mode, with sample index 582
#  => test mode, with sample index 583
#  => test mode, with sample index 584
#  => test mode, with sample index 585
#  => test mode, with sample index 586
#  => test mode, with sample index 587
#  => test mode, with sample index 588
#  => test mode, with sample index 589
#  => test mode, with sample index 590
#  => test mode, with sample index 591
#  => test mode, with sample index 592
#  => test mode, with sample index 593
#  => test mode, with sample index 594
#  => test mode, with sample index 595
#  => test mode, with sample index 596
#  => test mode, with sample index 597
#  => test mode, with sample index 598
#  => test mode, with sample index 599
#  => test mode, with sample index 600
#  => test mode, with sample index 601
#  => test mode, with sample index 602
#  => test mode, with sample index 603
#  => test mode, with sample index 604
#  => test mode, with sample index 605
#  => test mode, with sample index 606
#  => test mode, with sample index 607
#  => test mode, with sample index 608
#  => test mode, with sample index 609
#  => test mode, with sample index 610
#  => test mode, with sample index 611
#  => test mode, with sample index 612
#  => test mode, with sample index 613
#  => test mode, with sample index 614
#  => test mode, with sample index 615
#  => test mode, with sample index 616
#  => test mode, with sample index 617
#  => test mode, with sample index 618
#  => test mode, with sample index 619
#  => test mode, with sample index 620
#  => test mode, with sample index 621
#  => test mode, with sample index 622
#  => test mode, with sample index 623
#  => test mode, with sample index 624
#  => test mode, with sample index 625
#  => test mode, with sample index 626
#  => test mode, with sample index 627
#  => test mode, with sample index 628
#  => test mode, with sample index 629
#  => test mode, with sample index 630
#  => test mode, with sample index 631
#  => test mode, with sample index 632
#  => test mode, with sample index 633
#  => test mode, with sample index 634
#  => test mode, with sample index 635
#  => test mode, with sample index 636
#  => test mode, with sample index 637
#  => test mode, with sample index 638
#  => test mode, with sample index 639
#  => test mode, with sample index 640
#  => test mode, with sample index 641
#  => test mode, with sample index 642
